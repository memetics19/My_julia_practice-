# %% [markdown]
# # My Function
# --------------------------------------

# %%
function f(x)
    root = 2*x^2 - 4
    return root
end
f(2)
# Out:
# 4

# %% [markdown]
# # Let's do some Latex thing
# ------------------------------------------------------------------
# $$f(x) = 2x^2 - 4$$
#
# $$f(q,y) = q*y$$

# %% [markdown]
# # Let's Do some loops now
# ----------------------------------------

# %%
for i = -10:10
    println(f(i))
end
# Out:
# 196
# 158
# 124
# 94
# 68
# 46
# 28
# 14
# 4
# -2
# -4
# -2
# 4
# 14
# 28
# 46
# 68
# 94
# 124
# 158
# 196

# %% [markdown]
# # let's now plot the graph
# -----------------------------------------

# %%
using Plots
plot(x,f(x))
